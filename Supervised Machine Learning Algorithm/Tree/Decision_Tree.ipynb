# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
from sklearn.datasets import load_iris
#Classification:
iris=load_iris()

# %%
print(iris["DESCR"])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
#Independent Variable:
X=pd.DataFrame(iris['data'],columns=['sepal length','sepal width','petal length','petal width'])
X
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#Dependent Variable:
Y=iris['target']

# %%
#Train-Test-Split
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=10,test_size=0.2)

# %%
classifier=DecisionTreeClassifier()

# %%
classifier.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test,Y_pred)

# %%
print(f"Accuracy is {acc}")
# Out:
# Accuracy is 0.9666666666666667

# %%
plt.figure(figsize=(12,8))
plot_tree(classifier,filled=True)

#plt.savefig("DT.png")
# Out:
# [Text(0.3076923076923077, 0.9285714285714286, 'x[2] <= 2.45\ngini = 0.665\nsamples = 120\nvalue = [40, 37, 43]'),
#  Text(0.23076923076923078, 0.7857142857142857, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(0.2692307692307693, 0.8571428571428572, 'True  '),
#  Text(0.38461538461538464, 0.7857142857142857, 'x[2] <= 4.75\ngini = 0.497\nsamples = 80\nvalue = [0, 37, 43]'),
#  Text(0.34615384615384615, 0.8571428571428572, '  False'),
#  Text(0.15384615384615385, 0.6428571428571429, 'x[3] <= 1.65\ngini = 0.057\nsamples = 34\nvalue = [0, 33, 1]'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 33\nvalue = [0, 33, 0]'),
#  Text(0.23076923076923078, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6153846153846154, 0.6428571428571429, 'x[3] <= 1.75\ngini = 0.159\nsamples = 46\nvalue = [0, 4, 42]'),
#  Text(0.38461538461538464, 0.5, 'x[1] <= 2.65\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4]'),
# ...

# %% [markdown]
# Each Node consists of the feature in which the split is made, gini impurity(measure node purity), total samples, and the samples in each class. So, for the root node the splitting is taking place on the 3rd feature which is the petal length. The first split is a pure split in which all the dataset belongs to Iris-Setosa class. So, basically if the petal length is less than or equal to 2.45cm it belongs to Iris-Setosa category. Any plant with a petal length greater than 2.45cm can be either Iris-Versicolour or Iris-Virginica. To differntiate, it again makes another split based on petal length and it goes on till level 6 where it makes a completely pure split.
#
# Here, we can see the obvious flaw of Decision tree, that is since there is no stopping criteria, it tends to overfit and create pure nodes.

# %%
from sklearn.datasets import load_diabetes

# %%
#Regression:
diabetes=load_diabetes()

# %%
print(diabetes['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
X2=pd.DataFrame(diabetes.data,columns=['age','sex','bmi','bp','s1','s2','s3','s4','s5','s6'])
Y2=diabetes['target']

# %%
x_train,x_test,y_train,y_test=train_test_split(X2,Y2,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
clf=DecisionTreeRegressor()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

print(f"mean absolute error: {mean_absolute_error(y_test,y_pred)}")
print(f"mean squared error: {mean_squared_error(y_test,y_pred)}")
print(f"root mean square error: {np.sqrt(mean_squared_error(y_test,y_pred))}")
# Out:
# mean absolute error: 61.0
# mean squared error: 5793.1353383458645
# root mean square error: 76.11264900360429

# %%
#Hyperparameter tuning:
params={
    'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5,6,35,20],
    'max_features':['auto','sqrt','log2']   
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(clf,param_grid=params,cv=5,scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')

grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 35, 20],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 2,
#  'max_features': 'sqrt',
#  'splitter': 'best'}

# %%
y_pred=grid.predict(x_test)

# %%
print(f"mean absolute error: {mean_absolute_error(y_test,y_pred)}")
print(f"mean squared error: {mean_squared_error(y_test,y_pred)}")
print(f"root mean square error: {np.sqrt(mean_squared_error(y_test,y_pred))}")
# Out:
# mean absolute error: 46.94786676368339
# mean squared error: 3437.201744287201
# root mean square error: 58.62765340935284

# %% [markdown]
# Metric	Before Tuning	After Tuning	Improvement (%)
# MAE	        61.0	         46.95	       23% ↓
# MSE	       5793.14	         3437.20	   41% ↓
# RMSE	   76.11	         58.63	       23% ↓

# %%
selectedmodel=DecisionTreeRegressor(criterion='poisson',max_depth=2,max_features='sqrt',splitter='best')

# %%
selectedmodel.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=2, max_features='sqrt')

# %%
from sklearn import tree
tree.plot_tree(selectedmodel,filled=True)

plt.show()
